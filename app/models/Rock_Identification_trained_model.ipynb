# %%
# Importing libraries
import fastai
fastai.__version__
# Out:
# '1.0.61'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from fastai import *
from fastai.vision import *

# %%
path = Path('data/imgcls')

# %%
def create_folder():
  path = Path('data/imgcls')
  dest = path/folder
  dest.mkdir(parents=True, exist_ok=True)

# %%
folder = 'obsidian'
file = '/content/data/imgcls/obsidian/obsidian.txt'
create_folder()

# %%
folder = 'granite'
file = '/content/data/imgcls/granite/granite.txt'
create_folder()

# %%
from google.colab import files
obsidian = files.upload()
# Out:
#      <input type="file" id="files-a1d7e80e-dda5-470f-83c5-61f9a4d8d6ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1d7e80e-dda5-470f-83c5-61f9a4d8d6ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving obsidian.txt to obsidian.txt

# %%
granite = files.upload()
# Out:
#      <input type="file" id="files-a64aa438-eb99-4c90-848d-cd72e03477ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a64aa438-eb99-4c90-848d-cd72e03477ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving granite.txt to granite.txt

# %%
classes = ['granite', 'obsidian'] # define your classes here

# %%
download_images('obsidian.txt'  , '/content/data/imgcls/obsidian/', max_pics=400)

# %%
download_images('granite.txt'  , '/content/data/imgcls/granite/', max_pics=400)

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# granite
# obsidian

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/vision/transform.py:247: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  ../aten/src/ATen/native/BatchLinearAlgebra.cpp:766.)
#   return _solve_func(B,A)[0][:,0]
# ...

# %%
data.classes
# Out:
# ['granite', 'obsidian']

# %%
data.show_batch(rows=4, figsize=(7,8))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3680: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3680: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['granite', 'obsidian'], 2, 366, 91)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.965887</td>
#       <td>0.447019</td>
#       <td>0.098901</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.728960</td>
#       <td>0.432480</td>
#       <td>0.098901</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.613384</td>
#       <td>0.371715</td>
#       <td>0.076923</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.574667</td>
#       <td>0.397432</td>
#       <td>0.087912</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='16' class='' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [16/20 01:30<00:22]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-5,3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.343801</td>
#       <td>0.312231</td>
#       <td>0.076923</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.323376</td>
#       <td>0.354832</td>
#       <td>0.065934</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
learn.save('stage-2')

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3680: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# ...

# %%
interp.plot_confusion_matrix()

# %%
interp.most_confused()
# Out:
# [('granite', 'obsidian', 3), ('obsidian', 'granite', 3)]

# %%
interp.plot_top_losses(4)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3680: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "

# %%
from fastai.widgets import ImageCleaner, DatasetFormatter
from fastai import *

# %%
losses, idxs = interp.top_losses()
top_loss_paths = data.valid_ds.x[idxs]

# %%
top_loss_paths
# Out:
# ImageList (91 items)
# Image (3, 183, 276),Image (3, 200, 200),Image (3, 500, 500),Image (3, 167, 301),Image (3, 194, 260)
# Path: data/imgcls

# %%
db = (ImageList.from_folder(path)
                   .split_none()
                   .label_from_folder()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3680: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3680: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
db
# Out:
# ImageDataBunch;
#
# Train: LabelList (457 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# granite,granite,granite,granite,granite
# Path: data/imgcls;
#
# Valid: LabelList (0 items)
# x: ImageList
#
# y: CategoryList
#
# Path: data/imgcls;
#
# Test: None

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn_cln)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3680: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3680: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=error_rate)
learn_cln.load('stage-2');

# %%
df = pd.read_csv(path/'cleaned.csv', header='infer')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-41-20339fa28d1e> in <module>()
# ----> 1 df = pd.read_csv(path/'cleaned.csv', header='infer')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data.classes
# Out:
# ['granite', 'obsidian']

# %%
path
# Out:
# PosixPath('data/imgcls')

# %%
img = open_image(path/'obsidian'/'00000014.jpg')
img
# Out:
# Image (3, 190, 265)

# %%
# Prepare ImageDataBunch with the same transformations - ideally run this once
# when the app loads
classes = ['granite', 'obsidian']
data1 = ImageDataBunch.single_from_classes(path, classes, ds_tfms=get_transforms(),
                                           size=224).normalize(imagenet_stats)
learn1 = cnn_learner(data1, models.resnet34)
learn1.load('stage-2')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (0 items)
# x: ImageList
#
# y: CategoryList
#
# Path: data/imgcls;
#
# Valid: LabelList (0 items)
# x: ImageList
#
# y: CategoryList
#
# Path: data/imgcls;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
pred_class, pred_idx, outputs = learn1.predict(img)
pred_class
# Out:
# Category tensor(1)

# %%
learn1.export()
